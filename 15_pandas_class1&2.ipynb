# %% [markdown]
# # Pandas Lecture - 1

# %%
import pandas as pd

# %%
df = pd.read_csv("E:\Technical\DS_AI_ML\ineuron_internship\pandas_learning\zomato.csv")

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
type (df)
# Out:
# pandas.core.frame.DataFrame

# %%
df1= df.head(20)

# %%
df1.to_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/test.csv")

# %%
pd.read_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/test.csv")
# Out:
#     Unnamed: 0                                                url  \
# 0            0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1            1  https://www.zomato.com/bangalore/spice-elephan...
# 2            2  https://www.zomato.com/SanchurroBangalore?cont...
# 3            3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4            4  https://www.zomato.com/bangalore/grand-village...
# 5            5  https://www.zomato.com/bangalore/timepass-dinn...
# 6            6  https://www.zomato.com/bangalore/rosewood-inte...
# 7            7  https://www.zomato.com/bangalore/onesta-banash...
# 8            8  https://www.zomato.com/bangalore/penthouse-caf...
# 9            9  https://www.zomato.com/bangalore/smacznego-ban...
# 10          10  https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 11          11  https://www.zomato.com/bangalore/cafe-shuffle-...
# 12          12  https://www.zomato.com/bangalore/the-coffee-sh...
# ...

# %%
df = pd.read_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/test.csv", header=None)

# %%
df
# Out:
#       0                                                  1   \
# 0    NaN                                                url
# 1    0.0  https://www.zomato.com/bangalore/jalsa-banasha...
# 2    1.0  https://www.zomato.com/bangalore/spice-elephan...
# 3    2.0  https://www.zomato.com/SanchurroBangalore?cont...
# 4    3.0  https://www.zomato.com/bangalore/addhuri-udupi...
# 5    4.0  https://www.zomato.com/bangalore/grand-village...
# 6    5.0  https://www.zomato.com/bangalore/timepass-dinn...
# 7    6.0  https://www.zomato.com/bangalore/rosewood-inte...
# 8    7.0  https://www.zomato.com/bangalore/onesta-banash...
# 9    8.0  https://www.zomato.com/bangalore/penthouse-caf...
# 10   9.0  https://www.zomato.com/bangalore/smacznego-ban...
# 11  10.0  https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 12  11.0  https://www.zomato.com/bangalore/cafe-shuffle-...
# 13  12.0  https://www.zomato.com/bangalore/the-coffee-sh...
# 14  13.0  https://www.zomato.com/bangalore/caf-eleven-ba...
# ...

# %%
df= pd.read_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/zomato.csv", na_values=["Banashankari", "Whitefield"])

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
df.dtypes
# Out:
# url                            object
# address                        object
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# phone                          object
# location                       object
# rest_type                      object
# dish_liked                     object
# cuisines                       object
# approx_cost(for two people)    object
# reviews_list                   object
# menu_item                      object
# listed_in(type)                object
# listed_in(city)                object
# dtype: object

# %%
df1= pd.read_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/zomato.csv")

# %%
df1.to_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/result.csv", index=False)

# %%
df1.to_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/result1.csv", index=False, header=False)

# %%
df1.to_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/result2.csv", index=False, header=False, sep="#")

# %%
df1.to_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/result2.csv", index=False, columns=["name", "phone", "location"])

# %%
new_df= df1.iloc[:10000]

# %%
new_df.to_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/result.csv", index=False)

# %%
new_df.describe()
# Out:
#               votes
# count  10000.000000
# mean     245.569200
# std      711.891229
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      178.000000
# max    16345.000000

# %%
new_df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
type(new_df["name"])
# Out:
# pandas.core.series.Series

# %%
type(new_df[["name", "votes"]])
# Out:
# pandas.core.frame.DataFrame

# %%
new_df[["name", "votes"]]
# Out:
#                                   name  votes
# 0                                Jalsa    775
# 1                       Spice Elephant    787
# 2                      San Churro Cafe    918
# 3                Addhuri Udupi Bhojana     88
# 4                        Grand Village    166
# ...                                ...    ...
# 9995  Sree Banashankari Donne Biriyani      0
# 9996                    Northern Bites      0
# 9997                      Cafe Arabica     69
# 9998      Swa-Desh A Family Restaurant      0
# 9999                Mayuri Andhra Mess      0
#
# [10000 rows x 2 columns]

# %%
df2= pd.read_excel("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/LUSID Excel - Business Agility - Making Simple Changes Quickly & Easily.xlsx", sheet_name='Create your instrument universe')

# %%
df2
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3    Unnamed: 4 Unnamed: 5  \
# 0          NaN         NaN        NaN         NaN           NaN        NaN
# 1          NaN         NaN        NaN         NaN           NaN        NaN
# 2          NaN         NaN        NaN         NaN           NaN        NaN
# 3          NaN         NaN        NaN         NaN           NaN        NaN
# 4          NaN         NaN        NaN         NaN           NaN        NaN
# ..         ...         ...        ...         ...           ...        ...
# 66         NaN         NaN        NaN         NaN  BBG0000D14P3     Active
# 67         NaN         NaN        NaN         NaN  BBG00FN3B5K8     Active
# 68         NaN         NaN        NaN         NaN  BBG000DQQNJ8     Active
# 69         NaN         NaN        NaN         NaN  BBG000BF6B57     Active
# 70         NaN         NaN        NaN         NaN  BBG000BRVH05     Active
#
# ...

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df3= pd.read_html("https://www.basketball-reference.com/players/i/ibakase01.html?utm_source=direct&utm_medium=Share&utm_campaign=ShareTool")

# %%
df3
# Out:
# [       Season   Age                                     Tm  \
#  0     2008-09  19.0  Did Not Play (other pro league—Spain)
#  1     2009-10  20.0                                    OKC
#  2     2010-11  21.0                                    OKC
#  3     2011-12  22.0                                    OKC
#  4     2012-13  23.0                                    OKC
#  5     2013-14  24.0                                    OKC
#  6     2014-15  25.0                                    OKC
#  7     2015-16  26.0                                    OKC
#  8     2016-17  27.0                                    TOT
#  9     2016-17  27.0                                    ORL
#  10    2016-17  27.0                                    TOR
#  11    2017-18  28.0                                    TOR
#  12    2018-19  29.0                                    TOR
#  13    2019-20  30.0                                    TOR
#  14    2020-21  31.0                                    LAC
# ...

# %%
for i in range(len(df3)):
    df3[i].to_csv(f"E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/df3{i}.csv", index=False)

# %%
type(df3)
# Out:
# list

# %%
len(df3)
# Out:
# 6

# %%
df3[0]
# Out:
#        Season   Age                                     Tm  \
# 0     2008-09  19.0  Did Not Play (other pro league—Spain)
# 1     2009-10  20.0                                    OKC
# 2     2010-11  21.0                                    OKC
# 3     2011-12  22.0                                    OKC
# 4     2012-13  23.0                                    OKC
# 5     2013-14  24.0                                    OKC
# 6     2014-15  25.0                                    OKC
# 7     2015-16  26.0                                    OKC
# 8     2016-17  27.0                                    TOT
# 9     2016-17  27.0                                    ORL
# 10    2016-17  27.0                                    TOR
# 11    2017-18  28.0                                    TOR
# 12    2018-19  29.0                                    TOR
# 13    2019-20  30.0                                    TOR
# 14    2020-21  31.0                                    LAC
# ...

# %%
df3[3].to_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/basketball.csv")

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import json

# %%
s= """{ 
  "name": "Shivang",
  "phone_no": 89787626,
  "comp": ["ineuron", "delloite", "wipro", "cgi"]
}
"""

# %%
s1= json.loads(s)

# %%
s1
# Out:
# {'name': 'Shivang',
#  'phone_no': 89787626,
#  'comp': ['ineuron', 'delloite', 'wipro', 'cgi']}

# %%
pd.DataFrame(s1)
# Out:
#       name  phone_no      comp
# 0  Shivang  89787626   ineuron
# 1  Shivang  89787626  delloite
# 2  Shivang  89787626     wipro
# 3  Shivang  89787626       cgi

# %%
type(s1)
# Out:
# dict

# %%
pd.DataFrame(s1,columns=['comp'])
# Out:
#        comp
# 0   ineuron
# 1  delloite
# 2     wipro
# 3       cgi

# %%
import requests
res= requests.get("https://api.github.com/repos/pandas-dev/pandas/issues")
js= res.json()

# %%
res
# Out:
# <Response [200]>

# %%
js
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47597',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47597/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47597/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/47597/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/47597',
#   'id': 1294043839,
#   'node_id': 'PR_kwDOAA0YD846150-',
#   'number': 47597,
#   'title': 'Added improvements in to_datetime Error reporting message',
#   'user': {'login': 'dannyi96',
#    'id': 15380498,
#    'node_id': 'MDQ6VXNlcjE1MzgwNDk4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15380498?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dannyi96',
#    'html_url': 'https://github.com/dannyi96',
# ...

# %%
js[1]["user"]
# Out:
# {'login': 'mousey92',
#  'id': 26246536,
#  'node_id': 'MDQ6VXNlcjI2MjQ2NTM2',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/26246536?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/mousey92',
#  'html_url': 'https://github.com/mousey92',
#  'followers_url': 'https://api.github.com/users/mousey92/followers',
#  'following_url': 'https://api.github.com/users/mousey92/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/mousey92/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/mousey92/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/mousey92/subscriptions',
#  'organizations_url': 'https://api.github.com/users/mousey92/orgs',
#  'repos_url': 'https://api.github.com/users/mousey92/repos',
#  'events_url': 'https://api.github.com/users/mousey92/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/mousey92/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
len(js)
# Out:
# 30

# %%
type(js)
# Out:
# list

# %%
for i in range(len(js)):
    print(js[i]["title"])
# Out:
# Added improvements in to_datetime Error reporting message
# BUG: Inconsistent handling of dropping levels in MultiIndex when using IndexSlice
# CI: flake8-pyi
# TST: added test for handling repeated keys when using Series.loc with Multiindex
# QST: pd.read_sql how to process with null char '\0'
# BUG: raised error when converting (`.dt.tz_convert`) a NaT Series
# ENH: Move CSSWarning to error/__init__.py per GH27656
# TST: added test for to_json when called on numbers exceeding the int64 limit
# TYP: return values in core/*.py
# BUG: Series map ignoring na_action for dict or series mapper
# DOC: Indicate `formatters` in `DataFrame.to_string` can specify `__index__`
# REF: share DTA/TDA.__init__
# BUG: loc aligning rhs with list indexer but not with scalar
# BUG: pandas.Series.describe() displays confusing information
# ENH: DTI/DTA.astype support non-nano
# BUG: Setting incompatible values into ea column raises instead of casting to object
# ...

# %%
for i in range(len(js)):
    print(js[i]["user"]["node_id"])
# Out:
# MDQ6VXNlcjE1MzgwNDk4
# MDQ6VXNlcjI2MjQ2NTM2
# MDQ6VXNlcjY2MTgxNjY=
# MDQ6VXNlcjQyOTgzMDUx
# MDQ6VXNlcjQ1MDM5MDYw
# MDQ6VXNlcjY4NjA5NTc=
# MDQ6VXNlcjE1NzIxMzEx
# MDQ6VXNlcjQyOTgzMDUx
# MDQ6VXNlcjY2MTgxNjY=
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjIzNjIwNTA2
# MDQ6VXNlcjgwNzg5Njg=
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjgwMTkwOTA5
# MDQ6VXNlcjgwNzg5Njg=
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjE3NjcwMTA=
# MDQ6VXNlcjExNTg1NDI=
# MDQ6VXNlcjMyMzY3OTQ=
# MDQ6VXNlcjYxOTM0NzQ0
# MDQ6VXNlcjY4MDUzMzk2
# MDM6Qm90NDE4OTgyODI=
# MDQ6VXNlcjE1OTcxNA==
# MDQ6VXNlcjQ1NTYyNDAy
# U_kgDOBcws0A
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjE1MTEzODk0
# MDQ6VXNlcjEwNjQ3MDgy
# MDQ6VXNlcjMxODU3ODc2
# MDQ6VXNlcjExMzY0OTY=

# %%
df4= pd.DataFrame(js)
df4.to_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/git.csv", index=False)

# %%
d_f=[]
for i in range(len(js)):
    d_f.append(js[i]["user"])
df5= pd.DataFrame(d_f)
df5.to_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/git_user.csv", index=False)

# %%
json_data = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
data = pd.DataFrame.from_records(json_data['user'])
data.head()
# Out:
#          login        id               node_id  \
# 0     dannyi96  15380498  MDQ6VXNlcjE1MzgwNDk4
# 1     mousey92  26246536  MDQ6VXNlcjI2MjQ2NTM2
# 2   twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# 3  johnmantios  42983051  MDQ6VXNlcjQyOTgzMDUx
# 4    flyly0755  45039060  MDQ6VXNlcjQ1MDM5MDYw
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/153804...
# 1  https://avatars.githubusercontent.com/u/262465...
# 2  https://avatars.githubusercontent.com/u/661816...
# 3  https://avatars.githubusercontent.com/u/429830...
# 4  https://avatars.githubusercontent.com/u/450390...
#
#                                         url                        html_url  \
# 0     https://api.github.com/users/dannyi96     https://github.com/dannyi96
# 1     https://api.github.com/users/mousey92     https://github.com/mousey92
# 2   https://api.github.com/users/twoertwein   https://github.com/twoertwein
# ...

# %%
pd.DataFrame([js[i]["user"] for i in range(len(js))])
# Out:
#                   login        id               node_id  \
# 0              dannyi96  15380498  MDQ6VXNlcjE1MzgwNDk4
# 1              mousey92  26246536  MDQ6VXNlcjI2MjQ2NTM2
# 2            twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# 3           johnmantios  42983051  MDQ6VXNlcjQyOTgzMDUx
# 4             flyly0755  45039060  MDQ6VXNlcjQ1MDM5MDYw
# 5                igonro   6860957  MDQ6VXNlcjY4NjA5NTc=
# 6             dataxerik  15721311  MDQ6VXNlcjE1NzIxMzEx
# 7           johnmantios  42983051  MDQ6VXNlcjQyOTgzMDUx
# 8            twoertwein   6618166  MDQ6VXNlcjY2MTgxNjY=
# 9                 phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 10               ntjess  23620506  MDQ6VXNlcjIzNjIwNTA2
# 11         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 12                phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# 13               Iqigai  80190909  MDQ6VXNlcjgwMTkwOTA5
# 14         jbrockmendel   8078968  MDQ6VXNlcjgwNzg5Njg=
# 15                phofl  61934744  MDQ6VXNlcjYxOTM0NzQ0
# ...

# %% [markdown]
# # # Pandas Lecture - 2

# %%
import pandas as pd

# %%
pckl= pd.read_csv("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/basketball.csv")

# %%
pckl.to_pickle("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/my_pickle")

# %%
pckl
# Out:
#     Unnamed: 0     Season   Age   Tm   Lg  Pos      G     GS      MP     FG  \
# 0            0    2009-10  20.0  OKC  NBA   PF    6.0    0.0   153.0   20.0
# 1            1    2010-11  21.0  OKC  NBA   PF   17.0   17.0   490.0   67.0
# 2            2    2011-12  22.0  OKC  NBA   PF   20.0   20.0   569.0   84.0
# 3            3    2012-13  23.0  OKC  NBA   PF   11.0   11.0   366.0   59.0
# 4            4    2013-14  24.0  OKC  NBA   PF   17.0   17.0   581.0   87.0
# 5            5    2015-16  26.0  OKC  NBA   PF   18.0   18.0   602.0   85.0
# 6            6    2016-17  27.0  TOR  NBA   PF   10.0   10.0   307.0   60.0
# 7            7    2017-18  28.0  TOR  NBA   PF   10.0    9.0   260.0   30.0
# 8            8    2018-19  29.0  TOR  NBA    C   24.0    0.0   500.0   92.0
# 9            9    2019-20  30.0  TOR  NBA    C   11.0    0.0   251.0   63.0
# 10          10    2020-21  31.0  LAC  NBA    C    2.0    0.0    18.0    3.0
# ...

# %%
h5_data= pd.HDFStore("E:/Technical/DS_AI_ML/ineuron_internship/pandas_learning/test.h5")

# %%
h5_data["obj"]= pckl
# Out:
# C:\Users\shiva\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['Season', 'Tm', 'Lg', 'Pos'], dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
h5_data["obj"]
# Out:
#     Unnamed: 0     Season   Age   Tm   Lg  Pos      G     GS      MP     FG  \
# 0            0    2009-10  20.0  OKC  NBA   PF    6.0    0.0   153.0   20.0
# 1            1    2010-11  21.0  OKC  NBA   PF   17.0   17.0   490.0   67.0
# 2            2    2011-12  22.0  OKC  NBA   PF   20.0   20.0   569.0   84.0
# 3            3    2012-13  23.0  OKC  NBA   PF   11.0   11.0   366.0   59.0
# 4            4    2013-14  24.0  OKC  NBA   PF   17.0   17.0   581.0   87.0
# 5            5    2015-16  26.0  OKC  NBA   PF   18.0   18.0   602.0   85.0
# 6            6    2016-17  27.0  TOR  NBA   PF   10.0   10.0   307.0   60.0
# 7            7    2017-18  28.0  TOR  NBA   PF   10.0    9.0   260.0   30.0
# 8            8    2018-19  29.0  TOR  NBA    C   24.0    0.0   500.0   92.0
# 9            9    2019-20  30.0  TOR  NBA    C   11.0    0.0   251.0   63.0
# 10          10    2020-21  31.0  LAC  NBA    C    2.0    0.0    18.0    3.0
# ...

# %%
h5_data.put("obj1", pckl, format="table")

# %%
h5_data.select("obj1", where= ["index>=10 and index<=15"])
# Out:
#     Unnamed: 0     Season   Age   Tm   Lg  Pos      G     GS      MP     FG  \
# 10          10    2020-21  31.0  LAC  NBA    C    2.0    0.0    18.0    3.0
# 11          11    2021-22  32.0  MIL  NBA   PF    6.0    0.0    22.0    4.0
# 12          12     Career   NaN  NaN  NBA  NaN  152.0  102.0  4119.0  654.0
# 13          13        NaN   NaN  NaN  NaN  NaN    NaN    NaN     NaN    NaN
# 14          14  6 seasons   NaN  OKC  NBA  NaN   89.0   83.0  2761.0  402.0
# 15          15  4 seasons   NaN  TOR  NBA  NaN   55.0   19.0  1318.0  245.0
#
#     ...    FT%    ORB    DRB    TRB    AST   STL    BLK    TOV     PF     PTS
# 10  ...  1.000    1.0    3.0    4.0    2.0   1.0    3.0    1.0    1.0    10.0
# 11  ...  0.500    2.0    8.0   10.0    0.0   0.0    0.0    2.0    1.0     9.0
# 12  ...  0.789  277.0  688.0  965.0  109.0  61.0  292.0  141.0  449.0  1608.0
# 13  ...    NaN    NaN    NaN    NaN    NaN   NaN    NaN    NaN    NaN     NaN
# ...

# %%
h5_data["obj1"]
# Out:
#     Unnamed: 0     Season   Age   Tm   Lg  Pos      G     GS      MP     FG  \
# 0            0    2009-10  20.0  OKC  NBA   PF    6.0    0.0   153.0   20.0
# 1            1    2010-11  21.0  OKC  NBA   PF   17.0   17.0   490.0   67.0
# 2            2    2011-12  22.0  OKC  NBA   PF   20.0   20.0   569.0   84.0
# 3            3    2012-13  23.0  OKC  NBA   PF   11.0   11.0   366.0   59.0
# 4            4    2013-14  24.0  OKC  NBA   PF   17.0   17.0   581.0   87.0
# 5            5    2015-16  26.0  OKC  NBA   PF   18.0   18.0   602.0   85.0
# 6            6    2016-17  27.0  TOR  NBA   PF   10.0   10.0   307.0   60.0
# 7            7    2017-18  28.0  TOR  NBA   PF   10.0    9.0   260.0   30.0
# 8            8    2018-19  29.0  TOR  NBA    C   24.0    0.0   500.0   92.0
# 9            9    2019-20  30.0  TOR  NBA    C   11.0    0.0   251.0   63.0
# 10          10    2020-21  31.0  LAC  NBA    C    2.0    0.0    18.0    3.0
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df1= df[df.dtypes[df.dtypes== "object"].index]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# shivang         object
# shivangs         int64
# dtype: object

# %%
df.dtypes== "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# shivang         True
# shivangs       False
# dtype: bool

# %%
df[df.dtypes[df.dtypes=="object"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked shivang
# 0           A/5 21171   NaN        S   shahi
# 1            PC 17599   C85        C   shahi
# 2    STON/O2. 3101282   NaN        S   shahi
# ...

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# shivang     object
# dtype: object

# %%
df1
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked shivang
# 0           A/5 21171   NaN        S   shahi
# 1            PC 17599   C85        C   shahi
# 2    STON/O2. 3101282   NaN        S   shahi
# ...

# %%
df1.describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# shivang         object
# shivangs         int64
# dtype: object

# %%
df2= df[df.dtypes[df.dtypes=="float64"].index]

# %%
[df.dtypes[df.dtypes=="float64"].index]
# Out:
# [Index(['Age', 'Fare'], dtype='object')]

# %%
df.dtypes=="float64"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# shivang        False
# shivangs       False
# dtype: bool

# %%
df[df.dtypes=="float64"].index
# Out:
# C:\Users\shiva\AppData\Local\Temp/ipykernel_10044/3444640247.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.dtypes=="float64"].index
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10044/3444640247.py in <module>
# ----> 1 df[df.dtypes=="float64"].index
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3447         # Do we have a (boolean) 1d indexer?
#    3448         if com.is_bool_indexer(key):
# -> 3449             return self._getitem_bool_array(key)
#    3450
#    3451         # We are left with two options: a single key, and a collection of keys,
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    3500         # check_bool_indexer will throw exception if Series key cannot
# ...

# %%
df.dtypes=="float64".index
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# shivang        False
# shivangs       False
# dtype: bool

# %%
df2
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df[["Name" , 'Fare']]
# Out:
#                                                   Name     Fare
# 0                              Braund, Mr. Owen Harris   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                               Heikkinen, Miss. Laina   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4                             Allen, Mr. William Henry   8.0500
# ..                                                 ...      ...
# 886                              Montvila, Rev. Juozas  13.0000
# 887                       Graham, Miss. Margaret Edith  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"  23.4500
# 889                              Behr, Mr. Karl Howell  30.0000
# 890                                Dooley, Mr. Patrick   7.7500
#
# [891 rows x 2 columns]

# %%
df["Name"][5:10:2]
# Out:
# 5                       Moran, Mr. James
# 7         Palsson, Master. Gosta Leonard
# 9    Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df["Ticket"][5:10]
# Out:
# 5    330877
# 6     17463
# 7    349909
# 8    347742
# 9    237736
# Name: Ticket, dtype: object

# %%
sorted(df["Ticket"])
# Out:
# ['110152',
#  '110152',
#  '110152',
#  '110413',
#  '110413',
#  '110413',
#  '110465',
#  '110465',
#  '110564',
#  '110813',
#  '111240',
#  '111320',
#  '111361',
#  '111361',
#  '111369',
#  '111426',
#  '111427',
#  '111428',
#  '112050',
#  '112052',
#  '112053',
#  '112058',
#  '112059',
#  '112277',
#  '112379',
#  '113028',
#  '113043',
#  '113050',
#  '113051',
#  '113055',
#  '113056',
#  '113059',
#  '113501',
#  '113503',
#  '113505',
#  '113505',
#  '113509',
#  '113510',
#  '113514',
#  '113572',
#  '113572',
#  '113760',
#  '113760',
#  '113760',
#  '113760',
#  '113767',
#  '113773',
#  '113776',
#  '113776',
#  '113781',
#  '113781',
#  '113781',
#  '113781',
#  '113783',
#  '113784',
#  '113786',
#  '113787',
#  '113788',
#  '113789',
#  '113789',
#  '113792',
#  '113794',
#  '113796',
#  '113798',
#  '113798',
#  '113800',
#  '113803',
#  '113803',
#  '113804',
#  '113806',
#  '113806',
#  '113807',
#  '11668',
#  '11668',
#  '11751',
#  '11751',
#  '11752',
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
for i in df.columns:
    print(df[i])
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# ...

# %%
for i in df.columns:
    print(df[[i]])
# Out:
#      PassengerId
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5
# ..           ...
# 886          887
# 887          888
# 888          889
# 889          890
# 890          891
#
# [891 rows x 1 columns]
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 1 columns]
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ...

# %%
df ['shivang']= "shahi"

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df ["shivangs"] = df ["PassengerId"]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Cabin"]
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
pd.Categorical(df["Cabin"])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
pd.Categorical(df["Sex"])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(df["Pclass"])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
ser= df['Cabin'][df['Cabin'].isnull()== True].index

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df['Cabin'].isnull()== True
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
df['Cabin'].isnull().sum()
# Out:
# 687

# %%
ser
# Out:
# Int64Index([  0,   2,   4,   5,   7,   8,   9,  12,  13,  14,
#             ...
#             878, 880, 881, 882, 883, 884, 885, 886, 888, 890],
#            dtype='int64', length=687)

# %%
len(ser)
# Out:
# 687

# %%
ser1 = df['Cabin'][df['Cabin'].isnull() == True]

# %%
ser1.index
# Out:
# Int64Index([  0,   2,   4,   5,   7,   8,   9,  12,  13,  14,
#             ...
#             878, 880, 881, 882, 883, 884, 885, 886, 888, 890],
#            dtype='int64', length=687)

# %%
len(ser1)
# Out:
# 687

# %%
df.iloc[ser]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  shivang      891 non-null    object
#  13  shivangs     891 non-null    int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 97.6+ KB

# %%
df5 = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep= '\t')

# %%
df5
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df5.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv

# %%
https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt

# %%
https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv

# %%
https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv

# %%
https://drive.google.com/file/d/1etGP85wJWsgqbsh3gX5oxc8dPKLMA1eT/view
